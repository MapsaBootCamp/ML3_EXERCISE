# %%
import torch

# Model
model = torch.hub.load("ultralytics/yolov5", "yolov5s")  # or yolov5n - yolov5x6, custom

# Images
# img = "https://ultralytics.com/images/zidane.jpg"  # or file, Path, PIL, OpenCV, numpy, list

# # Inference
# results = model(img) ##       predict 

# # Results
# results.print()
# Out:
# Using cache found in /home/jovyan/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-3-9 Python-3.10.6 torch-1.13.1+cu117 CPU
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
#   0%|          | 0.00/14.1M [00:00<?, ?B/s]
# Fusing layers...
# [W NNPACK.cpp:53] Could not initialize NNPACK! Reason: Unsupported hardware.
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
# Images
from PIL import Image
 
# creating a object
img = Image.open('webcampic.png')
# img = "/webcampic.png"  # or file, Path, PIL, OpenCV, numpy, list

# Inference
results = model(img) ##       predict 

# Results
results.show()
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>
