# %%
# !pip install hazm
# Out:
# Collecting hazm
#   Downloading hazm-0.7.0-py3-none-any.whl (316 kB)
# Collecting nltk==3.3
#   Downloading nltk-3.3.0.zip (1.4 MB)
# Requirement already satisfied: six in c:\users\mehrdad\desktop\sample_project_1\env\lib\site-packages (from nltk==3.3->hazm) (1.16.0)
# Building wheels for collected packages: nltk
#   Building wheel for nltk (setup.py): started
#   Building wheel for nltk (setup.py): finished with status 'done'
#   Created wheel for nltk: filename=nltk-3.3-py3-none-any.whl size=1394484 sha256=ec2ebcde42cce0583303bd620e245e26051ddfe20296b727597f5a9dae470f87
#   Stored in directory: c:\users\mehrdad\appdata\local\pip\cache\wheels\ac\62\f6\88933dadcd64a1614894614aa68cf57c4b8e5256acb650b1f1
# Successfully built nltk
# Installing collected packages: nltk, hazm
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.7
#     Uninstalling nltk-3.7:
#       Successfully uninstalled nltk-3.7
# Successfully installed hazm-0.7.0 nltk-3.3

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import hazm

# %%
from hazm import stopwords_list

# %%
stopwords_list()

# %%
# !pip3 install wordcloud-fa
# Out:
# Collecting wordcloud-fa
#   Downloading wordcloud_fa-0.1.10-py3-none-any.whl (71 kB)
# Collecting python-bidi==0.4.2
#   Downloading python_bidi-0.4.2-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: matplotlib>=3.1.2 in c:\users\mehrdad\desktop\sample_project_1\env\lib\site-packages (from wordcloud-fa) (3.5.1)
# Requirement already satisfied: wordcloud==1.8.2.2 in c:\users\mehrdad\desktop\sample_project_1\env\lib\site-packages (from wordcloud-fa) (1.8.2.2)
# Requirement already satisfied: hazm==0.7.0 in c:\users\mehrdad\desktop\sample_project_1\env\lib\site-packages (from wordcloud-fa) (0.7.0)
# Requirement already satisfied: numpy>=1.18.1 in c:\users\mehrdad\desktop\sample_project_1\env\lib\site-packages (from wordcloud-fa) (1.22.3)
# Collecting arabic-reshaper>=2.1.3
#   Downloading arabic_reshaper-2.1.4-py3-none-any.whl (20 kB)
# Requirement already satisfied: pillow>=7.0.0 in c:\users\mehrdad\desktop\sample_project_1\env\lib\site-packages (from wordcloud-fa) (9.0.1)
# Requirement already satisfied: nltk==3.3 in c:\users\mehrdad\desktop\sample_project_1\env\lib\site-packages (from hazm==0.7.0->wordcloud-fa) (3.3)
# Requirement already satisfied: six in c:\users\mehrdad\desktop\sample_project_1\env\lib\site-packages (from nltk==3.3->hazm==0.7.0->wordcloud-fa) (1.16.0)
# Collecting future
#   Downloading future-0.18.2.tar.gz (829 kB)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mehrdad\desktop\sample_project_1\env\lib\site-packages (from matplotlib>=3.1.2->wordcloud-fa) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\mehrdad\desktop\sample_project_1\env\lib\site-packages (from matplotlib>=3.1.2->wordcloud-fa) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\mehrdad\desktop\sample_project_1\env\lib\site-packages (from matplotlib>=3.1.2->wordcloud-fa) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\mehrdad\desktop\sample_project_1\env\lib\site-packages (from matplotlib>=3.1.2->wordcloud-fa) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mehrdad\desktop\sample_project_1\env\lib\site-packages (from matplotlib>=3.1.2->wordcloud-fa) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mehrdad\desktop\sample_project_1\env\lib\site-packages (from matplotlib>=3.1.2->wordcloud-fa) (1.4.2)
# Building wheels for collected packages: future
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=62b8b6804ed7dc532ff04c0eb7627e677d057ce46a3b7e1a852252cd1022751a
#   Stored in directory: c:\users\mehrdad\appdata\local\pip\cache\wheels\2f\a0\d3\4030d9f80e6b3be787f19fc911b8e7aa462986a40ab1e4bb94
# Successfully built future
# Installing collected packages: future, python-bidi, arabic-reshaper, wordcloud-fa
# Successfully installed arabic-reshaper-2.1.4 future-0.18.2 python-bidi-0.4.2 wordcloud-fa-0.1.10

# %%
from wordcloud_fa import WordCloudFa

wc = WordCloudFa()

# %%
with open('raesi.txt', 'r',encoding="utf8") as file:
    text = file.read()

# %%
word_cloud = wc.generate(text)

# %%
plt.figure(figsize = (6, 6), facecolor = None)
plt.imshow(word_cloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
