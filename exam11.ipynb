# %% [markdown]
# ۱-چیست و شرط لازم برای استفاده از آنها چیستensemble learning روش های

# %% [markdown]
# Boosting(AdaBoost,Gradient Tree Boosting ,XGBoost)
# voting(hard , soft)
# stacking
# Bagging,pasting
# Random Forest

# %% [markdown]
# مدل هایی که استفاده میکنیم دارای بایاس یا واریانس بالا باشند از ترکیب مدل ها استفاده میکنیم یا هنگامی که مسله دارای پیچیدگی زمانی زیاد است و یا داده های مسئله خیلی کم یا خیلی زیاد باشد و هنگامی که بخواهیم به سطح اطمینان خوبی برسیم و به یک مدل نمیتوانیم اعتماد کنیم
# There are two main reasons to use an ensemble over a single model, and they are
# related; they are:
# Performance: An ensemble can make better predictions and achieve better
# performance than any single contributing model.
# Robustness: An ensemble reduces the spread or dispersion of the predictions
# and model performance.

# %% [markdown]
# ۲- را برای بهبود پیشنهاد میدهید ensembleشرکتی چند مدل برای پیش بینی قیمت نهایی کالا ترین کرده ولی همه ی آنها حتی روی داده های ترین هم به خوبی پاسخگو نیستند کدام روش

# %% [markdown]
# ۳- دو معیار برای پیدا کردن ریشه در درخت تصمیم چیست و سه الگوریتم برای ایجاد آن را نام ببرید

# %% [markdown]
# Information gain
# Gain ratio
# Gini index
# Entropy

# %% [markdown]
# ID3:Iterative Dichotomiser
# C4.5: Classiﬁer 4.5
# CART: Classification And Regression Tree
# ID4
# ds CART: DempsterShafer  Classification And Regression Tree
# ID5R
# EC4.5:Efficient Classiﬁer 4.5
# CHAID: Chi square Automatic Interaction Detection
# RF: Random Forest
# RT: Random Tree
# DS: Decision Stump
# QUEST: Quick Unbiased  Efficient Statistical Tree

# %% [markdown]
# ۴-  چی بودbootstrapمنظور از

# %% [markdown]
# bootstrapping is a resampling technique that involves repeatedly drawing
# samples from our source data with replacement, often to estimate a population
# parameter. By “with replacement”, we mean that the same data point may be
# included in our resampled dataset multiple times.

# %% [markdown]
# ۵-  را میتوان روی داده های لیبل دار زد ؟ چه روشی پیشنهاد شماست؟pcaآیا

# %%
بله در واقع unsupervised در pca به این معنی است که به لیبل داده ها
توجه نمیکند ولی برای هر دو مدل قابل استفاده است 
LDA

# %%
۶-نیاز به استقلال دارد random forest چرا

# %% [markdown]
# An individual tree in a random forest is just a decision tree trained on a
# random subset of the full feature space. Therefore, trees are not independent
# of one another, as they depend on the same set of data.
# Bootstrap Aggregation (i.e bagging), is a technique in which the same model is
# trained independently on bootstrapped samples of the full dataset. See Are
# observations independent in bootstrapped resamples? for a discussion of whether
# bootstrapped observations are independent. The TL;DR is that samples are
# independent with respect to the observed dataspace, but not the full dataspace

# %% [markdown]
# ‍7-  دو دیتای داده شده را با درخت تصمیم پیش بینی کرده و درخت را پرینت بگیریدirisروی دیتاست

# %%
[6.1, 2.8, 1.8, 1.9],
[8.1, 2.1, 2.5, 2.9]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.svm import SVC
from sklearn import tree
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %%
from sklearn.datasets import load_iris
iris = load_iris()
X, y = iris.data, iris.target
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, y)

# %%
tree.plot_tree(clf)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[2] <= 2.45\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.5769230769230769, 0.75, 'x[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.3076923076923077, 0.5833333333333334, 'x[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'x[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5384615384615384, 0.25, 'x[2] <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
# ...

# %%
df = pd.read_csv('heart.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
X = df.drop("target", axis=1)
y = df["target"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, 
                                                    random_state = 101)
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
dt = DecisionTreeClassifier(criterion="entropy" ,max_depth=4)
                            
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=42)

# %%
#from sklearn.tree import export_graphviz
# from sklearn.externals.six import StringIO
# from IPython.display import Image
# import pydotplus
# dot_data = StringIO()
# export_graphviz(clf, out_file=dot_data, filled=True, rounded=True,
#    special_characters=True,feature_names = feature_cols,class_names=['0','1'])
 
# graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
# graph.write_png('HEART_Tree.png')
# Image(graph.create_png())

# %%
tree.plot_tree(dt)
# Out:
# [Text(0.4791666666666667, 0.9, 'x[2] <= -0.443\ngini = 0.497\nsamples = 227\nvalue = [105, 122]'),
#  Text(0.2708333333333333, 0.7, 'x[11] <= -0.224\ngini = 0.397\nsamples = 110\nvalue = [80, 30]'),
#  Text(0.16666666666666666, 0.5, 'x[12] <= 0.331\ngini = 0.497\nsamples = 50\nvalue = [23, 27]'),
#  Text(0.08333333333333333, 0.3, 'x[7] <= -1.286\ngini = 0.358\nsamples = 30\nvalue = [7, 23]'),
#  Text(0.041666666666666664, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.125, 0.1, 'gini = 0.293\nsamples = 28\nvalue = [5, 23]'),
#  Text(0.25, 0.3, 'x[9] <= -0.427\ngini = 0.32\nsamples = 20\nvalue = [16, 4]'),
#  Text(0.20833333333333334, 0.1, 'gini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.2916666666666667, 0.1, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.375, 0.5, 'x[0] <= 0.961\ngini = 0.095\nsamples = 60\nvalue = [57, 3]'),
#  Text(0.3333333333333333, 0.3, 'gini = 0.0\nsamples = 45\nvalue = [45, 0]'),
# ...

# %% [markdown]
# ۸- روی دیتای پیش بینی بیماری قلبی با استفاده از
#  درsvmالگوریتم
# greed search
# وrandom search
# پیش بینی را انجام دهید

# %%
model = SVC()
model.fit(X_train, y_train)
predictions = model.predict(X_test)
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.76      0.82        37
#            1       0.80      0.92      0.86        39
#
#     accuracy                           0.84        76
#    macro avg       0.85      0.84      0.84        76
# weighted avg       0.85      0.84      0.84        76

# %%
param_search = {'C': [0.1, 1, 10, 100, 1000], 
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf']}

# %%
grid = GridSearchCV(SVC(), param_search, refit = True, verbose = 3)
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.543 total time=   0.0s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.565 total time=   0.0s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.556 total time=   0.0s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.556 total time=   0.0s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.556 total time=   0.0s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.739 total time=   0.0s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.717 total time=   0.0s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.778 total time=   0.0s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.822 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.587 total time=   0.0s
# ...

# %%
print(grid.best_params_)
print(grid.best_estimator_)
# Out:
# {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# SVC(C=100, gamma=0.001)

# %%
grid_predictions = grid.predict(X_test)
print(classification_report(y_test, grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.76      0.84        37
#            1       0.80      0.95      0.87        39
#
#     accuracy                           0.86        76
#    macro avg       0.87      0.85      0.85        76
# weighted avg       0.87      0.86      0.85        76

# %%
random = RandomizedSearchCV(SVC(), param_search, refit = True, verbose = 3)
random.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.761 total time=   0.0s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.696 total time=   0.0s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.822 total time=   0.0s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.711 total time=   0.0s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.822 total time=   0.0s
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.543 total time=   0.0s
# [CV 2/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.565 total time=   0.0s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.556 total time=   0.0s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.556 total time=   0.0s
# [CV 5/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.556 total time=   0.0s
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.891 total time=   0.0s
# ...

# %%
print(random.best_params_)
print(random.best_estimator_)
# Out:
# {'kernel': 'rbf', 'gamma': 0.001, 'C': 100}
# SVC(C=100, gamma=0.001)

# %%
random_predictions = random.predict(X_test)
print(classification_report(y_test, grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.76      0.84        37
#            1       0.80      0.95      0.87        39
#
#     accuracy                           0.86        76
#    macro avg       0.87      0.85      0.85        76
# weighted avg       0.87      0.86      0.85        76

# %% [markdown]
# ## linux

# %% [markdown]
# 1-برای تنظیمات گراب بهتر است کدوم فولدر تغییر داده شود

# %% [markdown]
# sudo gedit /boot/grub/grub.cfg

# %% [markdown]
# 2-
# شما برنامه ای را برای پیش بینی قیمت کالا نوشته اید این برمامه برای ران شدن احتیاج به خواندن ورودی به عنوان کانفیگ دارد کانفیگ های برنامه بهتر است چگونه و در کجا اعمال شوند

# %% [markdown]
# 3-به نظر شما نود پرینتر یا هر سخت افزار در کدام فولدر ذخیره میشود

# %% [markdown]
# این فایل ها در مسیر فایل سیستم /proc قرار دارند
# برای این کار با دستورات
# cat یا less و more
# می توان این فایل ها را بررسی کرد

# %% [markdown]
# 4-چیست bios کار

# %%
بوت کردن سیستم عامل

# %%
5- منظور از ~ چیست

# %% [markdown]
# ~/ is shorthand for the current user's home folder
