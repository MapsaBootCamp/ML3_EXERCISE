# %% [markdown]
# #### 1- read https://quera.org/problemset/125361/ train dataset comments and show it with WordCloud

# %% [markdown]
# #### 2- as you see the apearance is awkward make fun with wordcloud-fa to rebuild it in better persian appearance

# %%
# !pip install wordcloud-fa
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting wordcloud-fa
#   Downloading wordcloud_fa-0.1.10-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.4/71.4 kB 107.9 kB/s eta 0:00:00 kB/s eta 0:00:01
# Requirement already satisfied: hazm==0.7.0 in /home/mhazad/.local/lib/python3.8/site-packages (from wordcloud-fa) (0.7.0)
# Collecting arabic-reshaper>=2.1.3
#   Downloading arabic_reshaper-2.1.4-py3-none-any.whl (20 kB)
# Requirement already satisfied: matplotlib>=3.1.2 in /home/mhazad/.local/lib/python3.8/site-packages (from wordcloud-fa) (3.5.1)
# Requirement already satisfied: numpy>=1.18.1 in /home/mhazad/.local/lib/python3.8/site-packages (from wordcloud-fa) (1.22.3)
# Requirement already satisfied: pillow>=7.0.0 in /usr/lib/python3/dist-packages (from wordcloud-fa) (7.0.0)
# Collecting python-bidi==0.4.2
#   Downloading python_bidi-0.4.2-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: wordcloud==1.8.2.2 in /home/mhazad/.local/lib/python3.8/site-packages (from wordcloud-fa) (1.8.2.2)
# Requirement already satisfied: nltk==3.3 in /home/mhazad/.local/lib/python3.8/site-packages (from hazm==0.7.0->wordcloud-fa) (3.3)
# Requirement already satisfied: libwapiti>=0.2.1 in /home/mhazad/.local/lib/python3.8/site-packages (from hazm==0.7.0->wordcloud-fa) (0.2.1)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from python-bidi==0.4.2->wordcloud-fa) (1.14.0)
# Requirement already satisfied: future in /usr/lib/python3/dist-packages (from arabic-reshaper>=2.1.3->wordcloud-fa) (0.18.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mhazad/.local/lib/python3.8/site-packages (from matplotlib>=3.1.2->wordcloud-fa) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /home/mhazad/.local/lib/python3.8/site-packages (from matplotlib>=3.1.2->wordcloud-fa) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/mhazad/.local/lib/python3.8/site-packages (from matplotlib>=3.1.2->wordcloud-fa) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/mhazad/.local/lib/python3.8/site-packages (from matplotlib>=3.1.2->wordcloud-fa) (3.0.8)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mhazad/.local/lib/python3.8/site-packages (from matplotlib>=3.1.2->wordcloud-fa) (4.33.3)
# Requirement already satisfied: cycler>=0.10 in /home/mhazad/.local/lib/python3.8/site-packages (from matplotlib>=3.1.2->wordcloud-fa) (0.11.0)
# Installing collected packages: python-bidi, arabic-reshaper, wordcloud-fa
# Successfully installed arabic-reshaper-2.1.4 python-bidi-0.4.2 wordcloud-fa-0.1.10

# %%
# Out:
# <PIL.Image.Image image mode=RGB size=1000x500 at 0x7F3246E80220>

# %% [markdown]
# #### another library is persian_wordcloud you can use it for combined persian and english words####

# %% [markdown]
# #### 3- make a regex pattern tha match only \etc\cat22 not( \etdc\cat22 or \etc\cat22f)

# %% [markdown]
# #### 4- what does ematizer and  tager do ?

# %% [markdown]
# #### 5- what is the difrence of these (regex)
#
# #### [^0-9-]
#
# #### [\D-]

# %% [markdown]
# ## from class question
# #### 6- make a regex for iran mobile numbers explain each part of it

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## review
# #### 7- read company_sales_data.csv with pandas
#
# #### add "profit" as x label and "Month number" as y label "company profit" as title
#
# #### ach month_number should show in x axis
#
# #### make it orange

# %% [markdown]
# #### 8- make the plaot with bokeh like titanic.html file
# #### x axis is age y axis is survived and bolding of circles are according to Fare
#
# #### when you hover each circle it should show some extra informations
