# %% [markdown]
# ### Question1

# %% [markdown]
# 1-مجموع دیتایی در فابل مربوط به سوال 1 داده شده و عکس هایی به صورت باینری است آنها را خوانده و شبکه زیر را روی آن پیاده سازی کنید در انتها نمودار مقایسه
# Q1
# accuracy val_accuracy
#
# loss val_loss
#
# را برای مدل خود رسم کنید
#
# راهنمایی:
#
# در ابتدا ابعاد عکس را بیابید

# %% [markdown]
# ![CaptureCNN2.png](data:image/png;base64,...)

# %%
import numpy as np
x_test = np.load('x_test.npy')
x_train = np.load('x_train.npy')
y_test = np.load('y_test.npy')
y_train = np.load('y_train.npy')

x_train.shape
# Out:
# (60000, 28, 28)

# %%
from tensorflow import keras
from tensorflow.keras import layers

import matplotlib.pyplot as plt

# %%
inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu", padding="same")(inputs)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding="same")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Flatten()(x)
x=layers.Dense(128, activation="relu")(x)
outputs = layers.Dense(10, activation="softmax")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 75s 40ms/step - loss: 0.2647 - accuracy: 0.9547 - val_loss: 0.0559 - val_accuracy: 0.9814
# Epoch 2/10
# 1875/1875 [==============================] - 60s 32ms/step - loss: 0.0601 - accuracy: 0.9816 - val_loss: 0.0597 - val_accuracy: 0.9825
# Epoch 3/10
# 1875/1875 [==============================] - 52s 28ms/step - loss: 0.0444 - accuracy: 0.9864 - val_loss: 0.0484 - val_accuracy: 0.9853
# Epoch 4/10
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.0382 - accuracy: 0.9888 - val_loss: 0.0452 - val_accuracy: 0.9853
# Epoch 5/10
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.0330 - accuracy: 0.9893 - val_loss: 0.0442 - val_accuracy: 0.9862
# Epoch 6/10
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.0270 - accuracy: 0.9918 - val_loss: 0.0396 - val_accuracy: 0.9894
# Epoch 7/10
# ...

# %%
plt.figure()
plt.plot(range(1,11), history.history["loss"], label="loss", color='green')
plt.plot(range(1,11), history.history["val_loss"], label="val_loss")
plt.legend()

# %%
plt.figure()
plt.plot(range(1,11), history.history["accuracy"], label="accuracy", color='green')
plt.plot(range(1,11), history.history["val_accuracy"], label="val_accuracy")
plt.legend()

# %% [markdown]
# ### Question2

# %% [markdown]
# را نام ببرید وفرق آنها با هم را توضیح دهید ACTIVATION انواع

# %% [markdown]
# 1.Rectified Linear Activation (ReLU)---> max(0.0, x):This means that if the input value (x) is negative, then a value 0.0 is returned, otherwise, the value is returned
#
# 2.Logistic (Sigmoid)--->1.0 / (1.0 + e^-x):The function takes any real value as input and outputs values in the range 0 to 1. The larger the input (more positive), the closer the output value will be to 1.0, whereas the smaller the input (more negative), the closer the output will be to 0.0.
#
# 3.Hyperbolic Tangent (Tanh)--->(e^x – e^-x) / (e^x + e^-x):The function takes any real value as input and outputs values in the range -1 to 1. The larger the input (more positive), the closer the output value will be to 1.0, whereas the smaller the input (more negative), the closer the output will be to -1.0
#
# Activation for Output Layers:
#
# 1.Linear--->The linear activation function is also called “identity” (multiplied by 1.0) or “no activation.”,This is because the linear activation function does not change the weighted sum of the input in any way and instead returns the value directly.
#
# 2.Logistic (Sigmoid)
#
# 3.Softmax--->e^x / sum(e^x):The softmax function outputs a vector of values that sum to 1.0 that can be interpreted as probabilities of class membership.It is related to the argmax function that outputs a 0 for all options and 1 for the chosen option. Softmax is a “softer” version of argmax that allows a probability-like output of a winner-take-all function.

# %% [markdown]
# ### Question3

# %% [markdown]
# 2-خورانده و  YOLO عکس های داده شده در فایل زیپ مربوطه را به عنوان داده جدید به
#
# مدل را با داده های جدید خود ترین کنید
#
# از مراحل کار اسکرین کرفته و کدهای مربوطه را نیز بنویسید
#
#
# راهنمایی
#
# استفاده کنید roboflowاز
#
#
# Q2

# %% [markdown]
# #############
#
# پاسخ در فایل مجزا

# %% [markdown]
# ### Linux

# %% [markdown]
# linux
# 1-  کامند های زیر چه میکنند
#
# ls *li*
#
# ls *li
#
# ls ??li*
#
# grep -rin "blah"
#
# grep -v "blah"
#
# egrep -v "^#|^$" ~
#
#
#
#
# 2- من میخواهم خروجی دستور زیر فقط بعد از شارپ را نشان دهد
#
# cat /etc/services
#
#
# 3- دستوری بنویسید که در پوشه
#
# log
#
# به دنبال فولدری به اسم شما بگردد

# %% [markdown]
# ########################

# %% [markdown]
# 1-
#
# ls li-> list all li directories and files
#
# ls *li-> list all directories ans files end to li
#
# ls *??li*-> all directories and files containes li in position 3 and 4 of name

# %% [markdown]
# grep -rin 'blah'-> show files and directories contains 'blah' in their names with line number, ignore case, recursively
#
# grep -v "blah"-> show files and directories which do not contain 'blah' in their names
#
# egrep -v "^#|^$" ~ -> do not show comments and empty lines- egrep= expression grep

# %% [markdown]
# 2-
#
# cat /etc/services | cut -d \#

# %% [markdown]
# 3-
#
# find /log/ -name Salvia
