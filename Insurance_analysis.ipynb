# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('train.csv')
df.columns = df.columns.str.replace(' ', '')
df.head()
# Out:
#      CustomerId  Age                EmploymentType GraduateOrNot  \
# 0  3JUN0VW6F043   34  Private Sector/Self Employed           Yes
# 1  VLHY2ABIR4QL   28  Private Sector/Self Employed           Yes
# 2  6E3F7UNXYNFF   28  Private Sector/Self Employed           Yes
# 3  JJ8R0ZRYWR31   32             Government Sector           Yes
# 4  2WGFUEX6IEHM   34  Private Sector/Self Employed           Yes
#
#    AnnualIncome  FamilyMembers  ChronicDiseases FrequentFlyer  \
# 0       1300000              6                0           Yes
# 1        750000              7                0           Yes
# 2        750000              6                0           Yes
# 3        800000              6                1            No
# 4        700000              4                1            No
#
#   EverTravelledAbroad TravelInsurance
# 0                  No              No
# 1                  No              No
# 2                  No              No
# 3                  No              No
# ...

# %%
# one
df1=df.shape
for i in df1:
  print(i,end=' ')
# Out:
# 1590 10

# %%
#two
average=np.round(df['AnnualIncome'].mean())
average
# Out:
# 928553.0

# %%
#three
df['EverTravelledAbroad'].value_counts()[1]
# Out:
# 302

# %%
#four
total=np.round(df['EmploymentType'].value_counts(normalize=True)*100)
total.to_frame()
# Out:
#                               EmploymentType
# Private Sector/Self Employed            73.0
# Government Sector                       27.0

# %%
#five
s = df.groupby(['ChronicDiseases'])['TravelInsurance'].value_counts(normalize=True)*100
s.to_frame()
# Out:
#                                  TravelInsurance
# ChronicDiseases TravelInsurance
# 0               No                     65.764192
#                 Yes                    34.235808
# 1               No                     62.471910
#                 Yes                    37.528090
