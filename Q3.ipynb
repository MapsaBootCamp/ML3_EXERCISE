# %%
pip install wordcloud

# %%
pip install nltk

# %%
import nltk

# %%
nltk.download('stopwords')

# %%
from nltk.corpus import stopwords

# %%
import wordcloud

# %% [markdown]
# 1- read https://quera.org/problemset/125361/ train dataset comments and show it with WordCloud

# %%
import pandas as pd
import numpy as np


df = pd.read_csv('train.csv')
df.head()
# Out:
#                                              comment                 date
# 0               مثل همیشه عالی مخصوصا برگر ایتالیایی  2021-10-10 16:15:06
# 1  اقا شاید من هیچ قاشق و چنگالی نداشته باشم! بای...  2021-04-23 18:01:53
# 2  خیلی خوشمزه بود ای کاش تنوع بیشتری بدین حلوا ر...  2021-05-31 04:18:20
# 3  خوب بود فقط نسبت به مبلغ مرغ بریان اندازه اون ...  2021-04-04 12:56:17
# 4  به موقع و خوب فقط پیک اجناس را تا درب واحد بال...  2021-04-09 14:35:00

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

comment_words = " ".join(df['comment'])

wordcloud = WordCloud(font_path="B-NAZANIN.TTF", width = 800, height = 800, 
                      background_color ='white', stopwords = stopwords.words('english'),
                      min_font_size = 10).generate(comment_words)
 
plt.figure(figsize = (3, 3), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %% [markdown]
# 2- as you see the apearance is awkward make fun with wordcloud-fa to rebuild it in better persian appearance

# %%
pip install hazm

# %%
pip install wordcloud_fa

# %%
from wordcloud_fa import WordCloudFa

# %%
from hazm import stopwords_list
stopwords_list()

# %%
comment_words = " ".join(df['comment'])


wordcloud = WordCloudFa(font_path="B-NAZANIN.TTF",width = 800, height = 800, background_color ='Black',stopwords=stopwords_list(), min_font_size = 10).generate(comment_words)
 
plt.figure(figsize = (5, 5))
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %% [markdown]
# 3- make a regex pattern tha match only \etc\cat22 not( \etdc\cat22 or \etc\cat22f)

# %%
"\\etc\\cat\d+"

# %% [markdown]
# 4- what does ematizer and  tager do ?
#
# تبدیل فعل به مصدر

# %% [markdown]
# 5- what is the difrence of these (regex)
# [^0-9-]
# [\D-]

# %% [markdown]
# 6- make a regex for iran mobile numbers explain each part of it

# %%
r"(\s+|^)((\+98)|0)?9\d{2}-?\d{3}-?\d{4}(\D|$)"

# %% [markdown]
# 7- read company_sales_data.csv with pandas

# %%
import pandas as pd
import numpy as np

df2 = pd.read_csv('company_sales_data.csv')
df2.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %% [markdown]
# add "profit" as x label and "Month number" as y label "company profit" as title

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig = plt.subplots(figsize = (15,5))
sns.barplot(x=df2["month_number"], y=df2["total_profit"], color='Green')
plt.title('Company profit')
plt.show()

# %%
import pandas as pd

df3 = pd.read_csv('titanic.csv')
df3.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# 8- make the plaot with bokeh like titanic.html file

# %%
from bokeh.plotting import figure, show
import matplotlib.pyplot as plt

plot = figure(width=400, height=400, tools="tap")
renderer = plot.circle(df3['Age'], df3['Survived'], size=50, selection_color="firebrick", nonselection_fill_alpha=0.2, nonselection_fill_color="blue", nonselection_line_color="firebrick", nonselection_line_alpha=1.0)

show(plot)
