# %% [markdown]
# #### 1- read https://quera.org/problemset/125361/ train dataset comments and show it with WordCloud

# %%
import seaborn as sns

# %%
df=pd.read_csv("train.csv")
df
# Out:
#                                                  comment                 date
# 0                   مثل همیشه عالی مخصوصا برگر ایتالیایی  2021-10-10 16:15:06
# 1      اقا شاید من هیچ قاشق و چنگالی نداشته باشم! بای...  2021-04-23 18:01:53
# 2      خیلی خوشمزه بود ای کاش تنوع بیشتری بدین حلوا ر...  2021-05-31 04:18:20
# 3      خوب بود فقط نسبت به مبلغ مرغ بریان اندازه اون ...  2021-04-04 12:56:17
# 4      به موقع و خوب فقط پیک اجناس را تا درب واحد بال...  2021-04-09 14:35:00
# ...                                                  ...                  ...
# 55995  حجم سالاد بسیار کم بود حجم محتوای ساندویچ هم ه...  2021-04-02 15:16:20
# 55996  سفارش من چلو کوبیده بود و اصلا راضی نبودم، گوش...  2021-09-04 02:01:01
# 55997  کیف غذا بسیار پایین بود … هیچوقت دیگه نخواهم س...  2021-02-03 14:34:38
# 55998        بیسکوییت مادر ساده به جای نارگیلیش فرستادید  2021-06-24 14:12:43
# 55999  خیلی عالی بود طعم و کیفیت، اندازشم کاملا دو نف...  2021-09-13 14:15:19
#
# [56000 rows x 2 columns]

# %%
from wordcloud_fa import WordCloudFa

wc = WordCloudFa()

# %%
text=" ".join(df["comment"])

# %%
word_cloud = wc.generate(text)

# %%
plt.figure(figsize = (6, 6), facecolor = None)
plt.imshow(word_cloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### 2- as you see the apearance is awkward make fun with wordcloud-fa to rebuild it in better persian appearance

# %%
import hazm

# %%
from hazm import stopwords_list

# %%
stw=hazm.stopwords_list()

# %%
from wordcloud import WordCloud

# %%
wordcloud = WordCloud(width = 800, height = 800,font_path="B-NAZANIN.TTF" 
                      ,background_color ='white',
                      min_font_size = 10).generate(x)

# %%
plt.figure(figsize = (6, 6), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
# Out:
# <PIL.Image.Image image mode=RGB size=1000x500 at 0x7F3246E80220>

# %% [markdown]
# #### another library is persian_wordcloud you can use it for combined persian and english words####

# %% [markdown]
# #### 3- make a regex pattern tha match only \etc\cat22 not( \etdc\cat22 or \etc\cat22f)

# %%
\\(?:etc)\\(?:cat22)\b

# %% [markdown]
# #### 4- what does ematizer and  tager do ?

# %% [markdown]
# <h3>لمتایزر کلمات را به مصدرش تبدیل میکند</h3>
#
# <h3>نقش کلماتدر جمله را برمیگرداند</h3>

# %% [markdown]
# #### 5- what is the difrence of these (regex)
#
# #### [^0-9-]
#
# #### [\D-]

# %% [markdown]
# <h3>در اولی نه تنها دیجیت ها بلکه علامت - رو هم قبول نمیکند
#      اما در دومی در توالی از عداد و دش (-) فقط دش هارا قبول میکند</h3>

# %% [markdown]
# ## from class question
# #### 6- make a regex for iran mobile numbers explain each part of it

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
(\+98|0)?9\d{2}\-?\d{3}\-?\d{4}(\D|$|^\s)

# %% [markdown]
# <h3>اولش +98 یا صفر بیاد یا نیاد     بعدش 2 رقم عدد بعدش - بیاد یا نیاد به همین ترتیب تا آخر    . در آخر هم  میگه انتهاش عدد یا اسپیس نباشه  یا انتهای جمله باشد</h3>

# %% [markdown]
# ## review
# #### 7- read company_sales_data.csv with pandas
#
# #### add "profit" as x label and "Month number" as y label "company profit" as title
#
# #### ach month_number should show in x axis
#
# #### make it orange

# %%
df=pd.read_csv("titanic.csv")

# %%
sns.catplot(x="Sex",y="Age",kind="bar",data=df)

# %%
sns.catplot(x="Sex",kind="count",data=df)

# %%
sns.catplot(x="SibSp",y="Age",kind="bar",data=df)

# %% [markdown]
# #### 8- make the plaot with bokeh like titanic.html file
# #### x axis is age y axis is survived and bolding of circles are according to Fare
#
# #### when you hover each circle it should show some extra informations
